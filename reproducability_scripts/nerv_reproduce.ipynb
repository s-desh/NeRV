# %% [markdown]
# reproducing big bunny

# %%
# !pip install pytorch_msssim

# %% [markdown]
# training and evaluating on big bunny

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 1200   --lower-width 96 --num-blocks 1 --dataset bunny --frame_gap 1 --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --suffix .pth --norm none --act swish --weight /kaggle/working/output/bunny_ab/bunny/embed1.25_40_512_1_fc_9_16_26__exp1.0_reduce2_low96_blk1_cycle1_gap1_e1200_warm240_b1_conv_lr0.0005_cosine_Fusion6_Strd5,2,2,2,2_SinRes_actswish_.pth/model_train_best.pth --outf --eval_only --dump_images

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 1200   --lower-width 96 --num-blocks 1 --dataset bunny --frame_gap 1 --outf bunny_ab --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --suffix .pth --norm none --act swish --weight /kaggle/working/output/bunny_ab/bunny/embed1.25_40_512_1_fc_9_16_26__exp1.0_reduce2_low96_blk1_cycle1_gap1_e1200_warm240_b1_conv_lr0.0005_cosine_Fusion6_Strd5,2,2,2,2_SinRes_actswish_.pth/model_latest.pth --eval_only --dump_images

# %% [markdown]
# training and evaluating on cholec

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 300   --lower-width 96 --num-blocks 1 --dataset cholec80_13 --frame_gap 1 --outf cholec80 --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --norm none --act swish

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 300   --lower-width 96 --num-blocks 1 --dataset cholec80_13 --frame_gap 1 --outf cholec80 --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --norm none --act swish  --weight /kaggle/working/output/cholec80/cholec80_13/embed1.25_40_512_1_fc_9_16_26__exp1.0_reduce2_low96_blk1_cycle1_gap1_e300_warm60_b1_conv_lr0.0005_cosine_Fusion6_Strd5,2,2,2,2_SinRes_actswish_/model_latest.pth --eval_only --dump_images
