# %% [markdown]
# checking the activation functions:

# %%
# !pip install pytorch_msssim

# %% [markdown]
# ReLU:

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 300   --lower-width 96 --num-blocks 1 --dataset bunny --frame_gap 1 --outf act_bunny --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --suffix .pth --norm none --act relu

# %% [markdown]
# SiLU

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 300   --lower-width 96 --num-blocks 1 --dataset bunny --frame_gap 1 --outf act_bunny --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --suffix .pth --norm none --act swish

# %% [markdown]
# softplus

# %%
# !python /kaggle/input/nerv-dataset/train_nerv.py -e 300   --lower-width 96 --num-blocks 1 --dataset bunny --frame_gap 1 --outf act_bunny --embed 1.25_40 --stem_dim_num 512_1  --reduction 2  --fc_hw_dim 9_16_26 --expansion 1  --single_res --loss Fusion6   --warmup 0.2 --lr_type cosine  --strides 5 2 2 2 2  --conv_type conv -b 1  --lr 0.0005 --suffix .pth --norm none --act softplus
